# %%
#import required libraries
import pandas as pd

# %%
#load  data from imdb_1000.csv into dataframe and display it
df=pd.read_csv('imdb_1000.csv')
df
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
#display info about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    976 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
#describe dataframe
df.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
#display first 10 rows from dataframe
df.iloc[1:10,:]
# Out:
#    star_rating                                          title content_rating  \
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# 1      Crime       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# ...

# %%
#display last 10 rows from dataframe object
df.tail(10)
# Out:
#      star_rating                                            title  \
# 969          7.4                              Law Abiding Citizen
# 970          7.4                                      Wonder Boys
# 971          7.4                               Death at a Funeral
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 969              R      Crime       109
# 970              R      Drama       107
# 971              R     Comedy        90
# 972          NC-17      Drama       112
# ...

# %%
# display rows from 100 index to 200 only
df.iloc[100:201,:]
# Out:
#      star_rating                               title content_rating  \
# 100          8.3    The Treasure of the Sierra Madre      NOT RATED
# 101          8.3     Monty Python and the Holy Grail             PG
# 102          8.3                   Full Metal Jacket              R
# 103          8.3                       The Apartment       APPROVED
# 104          8.3                               Ikiru      NOT RATED
# 105          8.3                       The Third Man      NOT RATED
# 106          8.3                             Snatch.              R
# 107          8.3              For a Few Dollars More       APPROVED
# 108          8.3                          Metropolis      NOT RATED
# 109          8.3                      Dil Chahta Hai      NOT RATED
# 110          8.3               2001: A Space Odyssey              G
# 111          8.3                    Some Like It Hot      NOT RATED
# 112          8.3                   L.A. Confidential              R
# ...

# %%
#change bydefauly index to title(title as row label)
#df.set_index("title")
df
# Out:
#                                                    star_rating content_rating  \
# title
# The Shawshank Redemption                                   9.3              R
# The Godfather                                              9.2              R
# The Godfather: Part II                                     9.1              R
# The Dark Knight                                            9.0          PG-13
# Pulp Fiction                                               8.9              R
# 12 Angry Men                                               8.9      NOT RATED
# The Good, the Bad and the Ugly                             8.9      NOT RATED
# The Lord of the Rings: The Return of the King              8.9          PG-13
# Schindler's List                                           8.9              R
# Fight Club                                                 8.9              R
# The Lord of the Rings: The Fellowship of the Ring          8.8          PG-13
# ...

# %%
#display rows from label 'The Dark Knight' to 'X-Men' by using loc
df.loc['The Dark Knight':'X-Men']
# Out:
#                                                    star_rating content_rating  \
# title
# The Dark Knight                                            9.0          PG-13
# Pulp Fiction                                               8.9              R
# 12 Angry Men                                               8.9      NOT RATED
# The Good, the Bad and the Ugly                             8.9      NOT RATED
# The Lord of the Rings: The Return of the King              8.9          PG-13
# Schindler's List                                           8.9              R
# Fight Club                                                 8.9              R
# The Lord of the Rings: The Fellowship of the Ring          8.8          PG-13
# Inception                                                  8.8          PG-13
# Star Wars: Episode V - The Empire Strikes Back             8.8             PG
# Forrest Gump                                               8.8          PG-13
# ...

# %%
#display all rows with star_rating greater than 7
df.loc[df['star_rating']>7]
# Out:
#                                                    star_rating content_rating  \
# title
# The Shawshank Redemption                                   9.3              R
# The Godfather                                              9.2              R
# The Godfather: Part II                                     9.1              R
# The Dark Knight                                            9.0          PG-13
# Pulp Fiction                                               8.9              R
# 12 Angry Men                                               8.9      NOT RATED
# The Good, the Bad and the Ugly                             8.9      NOT RATED
# The Lord of the Rings: The Return of the King              8.9          PG-13
# Schindler's List                                           8.9              R
# Fight Club                                                 8.9              R
# The Lord of the Rings: The Fellowship of the Ring          8.8          PG-13
# ...

# %%
#display all rows with star_rating greater than 7 and less than 9
df.loc[(df['star_rating']>7) & (df['star_rating']<9)]
# Out:
#                                                    star_rating content_rating  \
# title
# Pulp Fiction                                               8.9              R
# 12 Angry Men                                               8.9      NOT RATED
# The Good, the Bad and the Ugly                             8.9      NOT RATED
# The Lord of the Rings: The Return of the King              8.9          PG-13
# Schindler's List                                           8.9              R
# Fight Club                                                 8.9              R
# The Lord of the Rings: The Fellowship of the Ring          8.8          PG-13
# Inception                                                  8.8          PG-13
# Star Wars: Episode V - The Empire Strikes Back             8.8             PG
# Forrest Gump                                               8.8          PG-13
# The Lord of the Rings: The Two Towers                      8.8          PG-13
# ...

# %%
#display all rows with genre==Crime
df.loc[df['genre'] == 'Crime']
# Out:
#                                   star_rating content_rating  genre  duration  \
# title
# The Shawshank Redemption                  9.3              R  Crime       142
# The Godfather                             9.2              R  Crime       175
# The Godfather: Part II                    9.1              R  Crime       200
# Pulp Fiction                              8.9              R  Crime       154
# City of God                               8.7              R  Crime       130
# The Usual Suspects                        8.7              R  Crime       106
# Leon: The Professional                    8.6              R  Crime       110
# American History X                        8.6              R  Crime       119
# The Green Mile                            8.5              R  Crime       189
# The Departed                              8.5              R  Crime       151
# M                                         8.4      NOT RATED  Crime        99
# ...

# %%
#count all rows with genre==Crime
data=df.loc[df['genre'] == 'Crime']
len(data)
# Out:
# 124

# %%
#select all rows with duration >100
df.loc[df['duration']>100]
# Out:
#                                                    star_rating content_rating  \
# title
# The Shawshank Redemption                                   9.3              R
# The Godfather                                              9.2              R
# The Godfather: Part II                                     9.1              R
# The Dark Knight                                            9.0          PG-13
# Pulp Fiction                                               8.9              R
# The Good, the Bad and the Ugly                             8.9      NOT RATED
# The Lord of the Rings: The Return of the King              8.9          PG-13
# Schindler's List                                           8.9              R
# Fight Club                                                 8.9              R
# The Lord of the Rings: The Fellowship of the Ring          8.8          PG-13
# Inception                                                  8.8          PG-13
# ...
